# %%
# yolo/yolov5/runs/train/exp4/weights/last.pt

import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/yolov5s.pt')
# Out:
# Using cache found in /Users/vichea/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-4-13 Python-3.9.6 torch-2.2.2 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
image = "card/images/4.jpg"
image
# Out:
# 'card/images/4.jpg'

# %%
results = model(image)

results.print()
# Out:
# image 1/1: 500x500 (no detections)
# Speed: 9.4ms pre-process, 231.8ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
import torch
import cv2
from PIL import Image
from torch.utils.data import DataLoader

# load pytorch model.pt

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = torch.load('model.pt', map_location=device)

# load image
image = Image.open('card/images/4.jpg').convert('RGB')
data_loader = DataLoader(image, batch_size=1, shuffle=False)


for batch_idx, (features, targets) in enumerate(data_loader):

    with torch.no_grad():
        features = features
        targets = targets
        logits = model(features.cuda())
        predictions = torch.argmax(logits, dim=1)
    break

fig, axes = plt.subplots(nrows=3, ncols=5,
                          sharex=True, sharey=True, figsize=(15,12
                                                             ))

nhwc_img = np.transpose(features, axes=(0, 2, 3, 1))
#nhwc_img = np.transpose(features, axes=(0, 2, 1))
#nhw_img = np.squeeze(nhwc_img.numpy(), axis=1)

for idx, ax in enumerate(axes.ravel()):
    ax.imshow(nhwc_img[idx], cmap='binary', aspect='auto')
    ax.title.set_text(f'P: {rev_dict[predictions[idx].item()]} | T: {rev_dict[predictions[idx].item()]}')
    ax.axison = False

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 16
#      12 image = Image.open('card/images/4.jpg').convert('RGB')
#      13 data_loader = DataLoader(image, batch_size=1, shuffle=False)
# ---> 16 for batch_idx, (features, targets) in enumerate(data_loader):
#      18     with torch.no_grad():
#      19         features = features
#
# File ~/github.com/machine-learning/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/github.com/machine-learning/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
# --> 674     index = self._next_index()  # may raise StopIteration
#     675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#
# File ~/github.com/machine-learning/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:621, in _BaseDataLoaderIter._next_index(self)
#     620 def _next_index(self):
# --> 621     return next(self._sampler_iter)
#
# File ~/github.com/machine-learning/env/lib/python3.9/site-packages/torch/utils/data/sampler.py:287, in BatchSampler.__iter__(self)
#     285 batch = [0] * self.batch_size
#     286 idx_in_batch = 0
# --> 287 for idx in self.sampler:
#     288     batch[idx_in_batch] = idx
#     289     idx_in_batch += 1
#
# File ~/github.com/machine-learning/env/lib/python3.9/site-packages/torch/utils/data/sampler.py:111, in SequentialSampler.__iter__(self)
#     110 def __iter__(self) -> Iterator[int]:
# --> 111     return iter(range(len(self.data_source)))
#
# TypeError: object of type 'Image' has no len()
